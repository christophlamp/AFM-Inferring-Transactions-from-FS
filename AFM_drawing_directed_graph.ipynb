# %%
import networkx as nx
print(nx.__version__)
# Out:
# 1.11

# %% [markdown]
# INPUT

# %%
nodelist = (["A1","A2","A3","A4","A5", "A6", "A7", "A8"]) #create nodes within directed graph

# %%
edgelist =([("A2","A1"),("A1","A4"),("A1","A5"),("A2","A8"),("A6","A2"),
                   ("A4","A8"),("A3","A7"),("A5","A8"),("A5","A3"),("A4","A3")])

# %% [markdown]
# PROCESSING

# %%
DG=nx.DiGraph()

# %%
DG.add_nodes_from(nodelist)

# %%
DG.add_edges_from(edgelist)

# %%
DG.number_of_nodes()
# Out:
# 8

# %%
DG.number_of_edges()
# Out:
# 10

# %%
import matplotlib.pyplot as plt #import drawing module

# %%
node_colors = ['lightblue']
node_labels = {node:node for node in DG.nodes()}
nx.draw_networkx_edges(DG, pos, arrows=True)
nx.draw(DG,pos, labels=node_labels, node_color = node_colors, node_size=400)

# %%
plt.show(DG)
